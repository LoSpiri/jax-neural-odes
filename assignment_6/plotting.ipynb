# %%
from SepsisDataset import SepsisDataset

# %%
dataset = SepsisDataset()
# Out:
#   0%|          | 0/20001 [00:00<?, ?it/s]

# %%
dataset.bar_plot_of_missing_values()

# %%
dataset._plot_distributions_for_each_column_with_outcomes()

# %%
dataset.boxplots_columns_and_outcomes()
